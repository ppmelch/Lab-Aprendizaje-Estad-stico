# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
import numpy as np

# %%
df = pd.read_csv('housing.csv')

# %%
# Grafica income vs precio caa
plt.scatter(df['median_income'], df['median_house_value'])

# %%
# Grafica sin los máx
df = df[df.median_house_value != df.median_house_value.max()]

# %%
plt.scatter(df['median_income'], df['median_house_value'])

# %% [markdown]
# ## Problema inicial: Quiero venderle casas a millonario, pero solo tengo datos de gente clase media, ¿cómo puedo estimar el valor de casas de millonarios?
#
# Pista: es un tanto lógico, que a mayor ingreso mensual mayor precio de la casa. La casa de una familia con ingreso mensual de 6000 dolares en promedio vale menos que la de una de 10,000

# %%
# Crea una regreson lineal
model= linear_model.LinearRegression()
X= df[['median_income']]
Y= df['median_house_value']

model.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# Intercepto : valor mínimo que va a valer una casa

# %%
model.intercept_
# Out:
# 45456.9967823186

# %% [markdown]
# Coeficiente: Por cada 1,000 dolares más que gana una familia al mes, cuanto tiende a crecer el valor de su casa

# %%
model.coef_
# Out:
# array([39987.01206231])

# %% [markdown]
# $$Precio = \beta_0 + \beta_1 X $$
#
# Mágicamente sklearn nos da esos numeros adaptados al problema, posteriormente ustedes verán como encontrar esos numeros
#
# $$Precio  = 45456 + 39987*ingreso$$

# %% [markdown]
# Llega un cliente millonario con ingreso mensual de 20,000 dolares y quiere vender su casa.
#
# ¿Cuál es el precio?

# %%
45456+39987* 20
# Out:
# 845196

# %% [markdown]
# ### ¿qué significan estos coeficientes?
#
# $\beta_0$ =  45456
#
# $\beta_1$ =  39987
#
# Cuando $\beta_1$ es 0 (es decir, el hogar no tiene ingresos) no tendría sentido decir que la casa no vale nada, las casas de la gente sin ingresos valen, por lo que la aproximación del modelo cuando la familia no tiene ingresos es de 45,456
#
# Para el caso de $\beta_1$ nos da que es 39987, viendo la ecuación tiene que ver con que por cada mil dolares que la familia tenga extra de ingreso mensual, el precio de la casa debe aumentar 39987

# %%
# ejemplo, familia de 4 mil dolares

a=45456 + 39987 * 4

# %%
# Familia de 5 mil dolares
b= 45456 + 39987 * 5

# %%
## diferencia
c= b-a
c
# Out:
# 39987

# %%
## La diferencia es exactamente igual a la estimación beta del model

# %% [markdown]
# ## ¿Qué tan bueno es el modelo?
#
# 1- Recordando que el modelo es simplemente --> 𝑃𝑟𝑒𝑐𝑖𝑜=45456+39987∗𝑖𝑛𝑔𝑟𝑒𝑠𝑜

# %%
# Aplicando el modelo
45456 + 39987 * X
# Out:
#        median_income
# 0        378355.7724
# 1        377404.0818
# 2        335657.6538
# 3        271106.6397
# 4        199253.9994
# ...              ...
# 20635    107847.7161
# 20636    147694.7616
# 20637    113433.9000
# 20638    120119.7264
# 20639    140968.9482
#
# [19675 rows x 1 columns]

# %%
# Scikit learn ya nos ahorra esto, nos da lo mismo
# Utilizaremos la función predict 
predicciones= model.predict(X)
predicciones
# Out:
# array([378356.8696035 , 377405.17871642, 335658.73812336, ...,
#        113434.91728825, 120120.74570507, 140969.97379436])

# %% [markdown]
# ### Visualizando el modelo

# %%
df['predicciones']= predicciones

# %%
# Visualiza las predicciones del modelo 
plt.scatter(df['median_income'], df['median_house_value'])
plt.scatter(df['median_income'], predicciones, color='red')

# %% [markdown]
# Observamos que ya podemos tener un modelo para familias que ganan mucho dinero al mes (arriba de 13 mil dolares por ejemplo)
#
# ¿Cuanto vale el precio de una casa de una familia millonaria que gana 15 mil dolares al mes?

# %%
model.predict([[15]])
# Out:
# c:\Users\ppmel\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([645262.17771704])

# %% [markdown]
# ### Midiendo el modelo
#
# #### Error cuadrático medio

# %%
np.mean(df.predicciones-df.median_house_value**2)
# Out:
# -46594611449.39812

# %%
from sklearn.metrics import mean_squared_error  
mean_squared_error(y_true=df.median_house_value, y_pred=df.predicciones)
# Out:
# 5604611138.03709

# %% [markdown]
# ¿Cuál es la diferencia entre las predicciones?

# %% [markdown]
# Ahhh pues saco el error promedio de esas diferencias

# %% [markdown]
# Sale un numero muy cerano a 0, ¿quiere decir que el modelo es buenisimo?
#
# No realmente, lo que pasa es que hay negativos y positivos. Es mejor sacar las diferencias al cuadrado para eliminar esos sesgos

# %% [markdown]
# Listo, ya tenemos una medida ... pero no es tan interpretable porque viene de un cuadrado

# %% [markdown]
# Obtenemos la raíz cuadrada

# %% [markdown]
# También podemos usar el paquete

# %% [markdown]
# ### R2 score
#
# Varianza de las casa = Varianza(precio de casas - promedio precios), representa la variabilidad total en los datos.
#
# Varianza de las predicciones = Varianza(precio de casas - predicción), representa la variabilidad no explicada por el modelo
#
# Uno pensaría, que si el modelo es bueno la varianza de las predicciones será mucho menor a la varianza de la casa (un modelo personalizado debe vencer a simplemente dar un promedio).
#
#
# $$r^2 = \frac{\text{Var}(y) - \text{Var}(y - \text{predicciones})}{\text{Var}(y)}$$

# %%
varianza_y=np.var(df.median_house_value)

# %%
varianza_predicciones = np.var(df.median_house_value - df.predicciones)

# %%
varianza_y
# Out:
# 9547053848.478031

# %%
varianza_predicciones
# Out:
# 5604611138.03709

# %%
varianza_y > varianza_predicciones
# Out:
# True

# %%
(varianza_y > varianza_predicciones) / varianza_y
# Out:
# 1.0474435526090781e-10

# %% [markdown]
# Utiliza sklearn para obtener el r2

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_true=df.median_house_value, y_pred=df.predicciones)
# Out:
# 0.4129486198582022

# %% [markdown]
# Conceptualmente: el modelo es un 42% mejor que simplemente dar el precio promedio de las casas como estimación

# %%
df.ocean_proximity.unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
df['near_bay']= df.ocean_proximity=='NEAR BAY'
df['less_1hour_ocean']= df.ocean_proximity=='<1H OCEAN'
df['inland']= df.ocean_proximity=='INLAND'
df['near_ocean']= df.ocean_proximity=='NEAR OCEAN'
df['island']= df.ocean_proximity=='ISLAND'

# %%
y= df['median_house_value']

# %%
# near bay
X = df[['near_bay']]
model = linear_model.LinearRegression().fit(X, y)

print(r2_score(y_true=y, y_pred=model.predict(X)))
print(model.coef_)
# Out:
# 0.024673194248851282
# [49747.28615467]

# %%
X = df[['inland']]
model = linear_model.LinearRegression().fit(X, y)

print(r2_score(y_true=y, y_pred=model.predict(X)))
print(model.coef_)
# Out:
# 0.24900926262721235
# [-103566.86093003]

# %%
X = df[['island']]
model = linear_model.LinearRegression().fit(X, y)


print(r2_score(y_true=y, y_pred=model.predict(X)))
print(model.coef_)
# Out:
# 0.000940668827222324
# [188009.85785458]

# %%
X = df[['near_ocean']]
model = linear_model.LinearRegression().fit(X, y)

print(r2_score(y_true=y, y_pred=model.predict(X)))
print(model.coef_)
# Out:
# 0.01846593279078712
# [40241.74368303]

# %%
df.groupby('ocean_proximity').agg({'median_house_value':['mean','count']})
# Out:
#                 median_house_value
#                               mean count
# ocean_proximity
# <1H OCEAN            224013.191539  8604
# INLAND               123252.620478  6524
# ISLAND               380440.000000     5
# NEAR BAY             236925.572519  2096
# NEAR OCEAN           227716.802944  2446

# %%
# less 1 hour

X= df[['inland']]
model= linear_model.LinearRegression().fit(X,y)

print(model.intercept_)
print(model.coef_)
# Out:
# 226819.4814082589
# [-103566.86093003]

# %% [markdown]
# Casa= 226819 + (-103566 * Inland)

# %%
df.query('inland==False').median_house_value.mean()
# Out:
# 226819.48140825794

# %%
list(model.predict(X))
# Out:
# [226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  123252.62047823229,
#  226819.4814082589,
#  123252.62047823229,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  226819.4814082589,
#  123252.62047823229,
#  226819.4814082589,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  226819.4814082589,
#  226819.4814082589,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  226819.4814082589,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  226819.4814082589,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  123252.62047823229,
#  ...]
